# %%
# !pip install easyocr
# !pip install imutils
# !pip install matplotlib
# Out:
# Requirement already satisfied: easyocr in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.6.0+cu118)
# Requirement already satisfied: torchvision>=0.5 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (0.21.0+cu118)
# Requirement already satisfied: opencv-python-headless in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (4.11.0.86)
# Requirement already satisfied: scipy in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (1.15.2)
# Requirement already satisfied: numpy in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: Pillow in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (11.0.0)
# Requirement already satisfied: scikit-image in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.0.7)
# Requirement already satisfied: pyclipper in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (1.11.1.4)
# Requirement already satisfied: filelock in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (4.13.0)
# Requirement already satisfied: networkx in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.3)
# Requirement already satisfied: jinja2 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from sympy==1.13.1->torch->easyocr) (1.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (2025.3.13)
# Requirement already satisfied: packaging>=21 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: imutils in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (0.5.4)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.56.0-cp313-cp313-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\cosmic\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.1-cp313-cp313-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.56.0-cp313-cp313-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pyparsing-3.2.3
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
img = cv2.imread('image2.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) 
edged = cv2.Canny(bfilter, 30, 200) 
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))
